# %%
# !pip install wandb -qU
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.4/21.4 MB 96.0 MB/s eta 0:00:00

# %%
# !pip install hydra-core --quiet
# Out:
# DEPRECATION: Loading egg at /usr/local/lib/python3.11/dist-packages/animaloc-0.2.1-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation. Discussion can be found at https://github.com/pypa/pip/issues/12330
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.5/154.5 kB 3.7 MB/s eta 0:00:00

# %%
import wandb
import random
import math

# %%
wandb.login()
# 7adbc9679e82154709a6abc3ba6faeb396927426
# Out:
# wandb: Logging into wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize
# wandb: Paste an API key from your profile and hit enter:
#  ··········
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: No netrc file found, creating one.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Currently logged in as: jpca92 (grupo_8) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# True

# %%
wandb.login()
# Out:
# True

# %%
import os
num_workers = os.cpu_count()
print(num_workers)
# Out:
# 12

# %%
# Download and install the code
import sys

# !git clone https://github.com/Alexandre-Delplanque/HerdNet
# !cd '/content/HerdNet' && python setup.py install

sys.path.append('/content/HerdNet')
# Out:
# Cloning into 'HerdNet'...
# remote: Enumerating objects: 570, done.
# remote: Counting objects: 100% (193/193), done.
# remote: Compressing objects: 100% (61/61), done.
# remote: Total 570 (delta 149), reused 132 (delta 132), pack-reused 377 (from 2)
# Receiving objects: 100% (570/570), 205.52 KiB | 2.60 MiB/s, done.
# Resolving deltas: 100% (370/370), done.
# running install
# /usr/local/lib/python3.11/dist-packages/setuptools/_distutils/cmd.py:66: SetuptoolsDeprecationWarning: setup.py install is deprecated.
# !!
#
#         ********************************************************************************
#         Please avoid running ``setup.py`` directly.
#         Instead, use pypa/build, pypa/installer or other
#         standards-based tools.
#
#         See https://blog.ganssle.io/articles/2021/10/setup-py-deprecated.html for details.
#         ********************************************************************************
#
# !!
#   self.initialize_options()
# ...

# %% [markdown]
# # Montar el google drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# !cp '/content/drive/MyDrive/Colab Notebooks/trabajo_grado/data.zip' /content/
# !unzip -oq /content/data.zip -d /content
# Out:
# Mounted at /content/drive

# %%
# Set the seed
from animaloc.utils.seed import set_seed

set_seed(9292)
# Out:
# /usr/local/lib/python3.11/dist-packages/albumentations/__init__.py:28: UserWarning: A new version of Albumentations is available: '2.0.7' (you have '2.0.6'). Upgrade using: pip install -U albumentations. To disable automatic update checks, set the environment variable NO_ALBUMENTATIONS_UPDATE to 1.
#   check_for_updates()

# %% [markdown]
# # Test primer modelo exitoso 54%

# %%
# %cd /content/HerdNet
# !python tools/test.py test=herdnet_test_model_059
# Out:
# /content/HerdNet
# /usr/local/lib/python3.11/dist-packages/albumentations/__init__.py:28: UserWarning: A new version of Albumentations is available: '2.0.7' (you have '2.0.6'). Upgrade using: pip install -U albumentations. To disable automatic update checks, set the environment variable NO_ALBUMENTATIONS_UPDATE to 1.
#   check_for_updates()
# /content/HerdNet/tools/test.py:128: UserWarning:
# The version_base parameter is not specified.
# Please specify a compatability version level, or None.
# Will assume defaults for version 1.1
#   @hydra.main(config_path='../configs', config_name="config")
# /usr/local/lib/python3.11/dist-packages/hydra/_internal/hydra.py:119: UserWarning: Future Hydra versions will no longer change working directory at job runtime by default.
# See https://hydra.cc/docs/1.2/upgrades/1.1_to_1.2/changes_to_job_working_dir/ for more information.
#   ret = run_job(
# ...

# %% [markdown]
# # Test del modelo uniandes 0.86

# %%
# %cd /content/HerdNet
# !python tools/test.py test=herdnet_test_colab_086
# Out:
# /content/HerdNet
# /usr/local/lib/python3.11/dist-packages/albumentations/__init__.py:28: UserWarning: A new version of Albumentations is available: '2.0.7' (you have '2.0.6'). Upgrade using: pip install -U albumentations. To disable automatic update checks, set the environment variable NO_ALBUMENTATIONS_UPDATE to 1.
#   check_for_updates()
# /content/HerdNet/tools/test.py:128: UserWarning:
# The version_base parameter is not specified.
# Please specify a compatability version level, or None.
# Will assume defaults for version 1.1
#   @hydra.main(config_path='../configs', config_name="config")
# /usr/local/lib/python3.11/dist-packages/hydra/_internal/hydra.py:119: UserWarning: Future Hydra versions will no longer change working directory at job runtime by default.
# See https://hydra.cc/docs/1.2/upgrades/1.1_to_1.2/changes_to_job_working_dir/ for more information.
#   ret = run_job(
# ...

# %% [markdown]
# # Test del modelo con finetuning colab

# %%
# %cd /content/HerdNet
# !python tools/test.py test=herdnet_test_colab
# Out:
# /content/HerdNet
# /usr/local/lib/python3.11/dist-packages/albumentations/__init__.py:28: UserWarning: A new version of Albumentations is available: '2.0.7' (you have '2.0.6'). Upgrade using: pip install -U albumentations. To disable automatic update checks, set the environment variable NO_ALBUMENTATIONS_UPDATE to 1.
#   check_for_updates()
# /content/HerdNet/tools/test.py:128: UserWarning:
# The version_base parameter is not specified.
# Please specify a compatability version level, or None.
# Will assume defaults for version 1.1
#   @hydra.main(config_path='../configs', config_name="config")
# /usr/local/lib/python3.11/dist-packages/hydra/_internal/hydra.py:119: UserWarning: Future Hydra versions will no longer change working directory at job runtime by default.
# See https://hydra.cc/docs/1.2/upgrades/1.1_to_1.2/changes_to_job_working_dir/ for more information.
#   ret = run_job(
# ...

# %% [markdown]
# # Test del modelo con finetuning uniandes

# %%
# %cd /content/HerdNet
# !python tools/test.py test=herdnet_test_uniandes
# Out:
# /content/HerdNet
# /usr/local/lib/python3.11/dist-packages/albumentations/__init__.py:28: UserWarning: A new version of Albumentations is available: '2.0.7' (you have '2.0.6'). Upgrade using: pip install -U albumentations. To disable automatic update checks, set the environment variable NO_ALBUMENTATIONS_UPDATE to 1.
#   check_for_updates()
# /content/HerdNet/tools/test.py:128: UserWarning:
# The version_base parameter is not specified.
# Please specify a compatability version level, or None.
# Will assume defaults for version 1.1
#   @hydra.main(config_path='../configs', config_name="config")
# /usr/local/lib/python3.11/dist-packages/hydra/_internal/hydra.py:119: UserWarning: Future Hydra versions will no longer change working directory at job runtime by default.
# See https://hydra.cc/docs/1.2/upgrades/1.1_to_1.2/changes_to_job_working_dir/ for more information.
#   ret = run_job(
# ...
